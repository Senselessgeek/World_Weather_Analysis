# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = zip(lats, lngs)

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
cities = [ ]
# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 748

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key1

# %%
# Assemble the OpenWeatherMap's API call
weather_api_key = weather_api_key1
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = [ ]

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
                # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_wdscrpt = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Weather": city_wdscrpt,
                          "Date": city_date})     
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | doume
# Processing Record 2 of Set 1 | ambilobe
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | shimoda
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | san patricio
# Processing Record 9 of Set 1 | tiblawan
# Processing Record 10 of Set 1 | vaini
# Processing Record 11 of Set 1 | ponta do sol
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | umzimvubu
# City not found. Skipping...
# Processing Record 14 of Set 1 | port alfred
# Processing Record 15 of Set 1 | airai
# Processing Record 16 of Set 1 | ngunguru
# Processing Record 17 of Set 1 | rincon de la victoria
# Processing Record 18 of Set 1 | rikitea
# Processing Record 19 of Set 1 | touros
# Processing Record 20 of Set 1 | qaqortoq
# Processing Record 21 of Set 1 | albany
# Processing Record 22 of Set 1 | egvekinot
# Processing Record 23 of Set 1 | tairua
# Processing Record 24 of Set 1 | batagay-alyta
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | tuktoyaktuk
# Processing Record 27 of Set 1 | byron bay
# Processing Record 28 of Set 1 | avarua
# Processing Record 29 of Set 1 | souillac
# Processing Record 30 of Set 1 | buru-un
# City not found. Skipping...
# Processing Record 31 of Set 1 | cape town
# Processing Record 32 of Set 1 | portland
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | new norfolk
# Processing Record 35 of Set 1 | aripuana
# Processing Record 36 of Set 1 | lavrentiya
# Processing Record 37 of Set 1 | krasnyy oktyabr
# Processing Record 38 of Set 1 | fortuna
# Processing Record 39 of Set 1 | leningradskiy
# Processing Record 40 of Set 1 | kodiak
# Processing Record 41 of Set 1 | sataua
# City not found. Skipping...
# Processing Record 42 of Set 1 | cidreira
# Processing Record 43 of Set 1 | ambulu
# Processing Record 44 of Set 1 | yellowknife
# Processing Record 45 of Set 1 | inhambane
# Processing Record 46 of Set 1 | beringovskiy
# Processing Record 47 of Set 1 | pacific grove
# Processing Record 48 of Set 1 | kiruna
# Processing Record 49 of Set 1 | lacey
# Processing Record 50 of Set 1 | lac du bonnet
# Processing Record 1 of Set 2 | coromandel
# Processing Record 2 of Set 2 | kroya
# Processing Record 3 of Set 2 | novikovo
# Processing Record 4 of Set 2 | geraldton
# Processing Record 5 of Set 2 | payo
# Processing Record 6 of Set 2 | jatai
# Processing Record 7 of Set 2 | uribia
# Processing Record 8 of Set 2 | awbari
# Processing Record 9 of Set 2 | hofn
# Processing Record 10 of Set 2 | tonantins
# Processing Record 11 of Set 2 | sur
# Processing Record 12 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 13 of Set 2 | kilindoni
# Processing Record 14 of Set 2 | misratah
# Processing Record 15 of Set 2 | hamilton
# Processing Record 16 of Set 2 | victoria
# Processing Record 17 of Set 2 | munster
# Processing Record 18 of Set 2 | palembang
# Processing Record 19 of Set 2 | ardakan
# Processing Record 20 of Set 2 | khatanga
# Processing Record 21 of Set 2 | nushki
# Processing Record 22 of Set 2 | oranjemund
# Processing Record 23 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 24 of Set 2 | qaanaaq
# Processing Record 25 of Set 2 | caravelas
# Processing Record 26 of Set 2 | hithadhoo
# Processing Record 27 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 28 of Set 2 | richards bay
# Processing Record 29 of Set 2 | tasiilaq
# Processing Record 30 of Set 2 | atuona
# Processing Record 31 of Set 2 | kapaa
# Processing Record 32 of Set 2 | hailar
# Processing Record 33 of Set 2 | puerto madero
# Processing Record 34 of Set 2 | abu dhabi
# Processing Record 35 of Set 2 | talara
# Processing Record 36 of Set 2 | dindori
# Processing Record 37 of Set 2 | torbay
# Processing Record 38 of Set 2 | lebu
# Processing Record 39 of Set 2 | port hardy
# Processing Record 40 of Set 2 | paamiut
# Processing Record 41 of Set 2 | mumbwa
# Processing Record 42 of Set 2 | esperance
# Processing Record 43 of Set 2 | hobart
# Processing Record 44 of Set 2 | college
# Processing Record 45 of Set 2 | lagoa
# Processing Record 46 of Set 2 | pulivendla
# Processing Record 47 of Set 2 | east london
# Processing Record 48 of Set 2 | arawa
# Processing Record 49 of Set 2 | hermanus
# Processing Record 50 of Set 2 | mount pleasant
# Processing Record 1 of Set 3 | quirinopolis
# Processing Record 2 of Set 3 | methoni
# Processing Record 3 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 4 of Set 3 | asau
# Processing Record 5 of Set 3 | chuy
# Processing Record 6 of Set 3 | kaz
# Processing Record 7 of Set 3 | saskylakh
# Processing Record 8 of Set 3 | faanui
# Processing Record 9 of Set 3 | ilulissat
# Processing Record 10 of Set 3 | bantry
# Processing Record 11 of Set 3 | jamestown
# Processing Record 12 of Set 3 | cortes
# Processing Record 13 of Set 3 | bogashevo
# Processing Record 14 of Set 3 | hualmay
# Processing Record 15 of Set 3 | huilong
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | tonj
# Processing Record 18 of Set 3 | bell ville
# Processing Record 19 of Set 3 | barrow
# Processing Record 20 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 21 of Set 3 | kruisfontein
# Processing Record 22 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 23 of Set 3 | amderma
# City not found. Skipping...
# Processing Record 24 of Set 3 | roald
# Processing Record 25 of Set 3 | bonthe
# Processing Record 26 of Set 3 | pangkalanbuun
# Processing Record 27 of Set 3 | castro
# Processing Record 28 of Set 3 | las palmas
# Processing Record 29 of Set 3 | terrace
# Processing Record 30 of Set 3 | kysyl-syr
# Processing Record 31 of Set 3 | mayo
# Processing Record 32 of Set 3 | saravena
# Processing Record 33 of Set 3 | kichera
# Processing Record 34 of Set 3 | tuatapere
# Processing Record 35 of Set 3 | halalo
# City not found. Skipping...
# Processing Record 36 of Set 3 | cabo san lucas
# Processing Record 37 of Set 3 | port elizabeth
# Processing Record 38 of Set 3 | san luis
# Processing Record 39 of Set 3 | honiara
# Processing Record 40 of Set 3 | robstown
# Processing Record 41 of Set 3 | pokrovsk-uralskiy
# City not found. Skipping...
# Processing Record 42 of Set 3 | clyde river
# Processing Record 43 of Set 3 | lazaro cardenas
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | mareeba
# Processing Record 46 of Set 3 | ribeira grande
# Processing Record 47 of Set 3 | komsomolskiy
# Processing Record 48 of Set 3 | puerto ayora
# Processing Record 49 of Set 3 | sitka
# Processing Record 50 of Set 3 | attawapiskat
# City not found. Skipping...
# Processing Record 1 of Set 4 | artyk
# City not found. Skipping...
# Processing Record 2 of Set 4 | klaksvik
# Processing Record 3 of Set 4 | mackay
# Processing Record 4 of Set 4 | dingle
# Processing Record 5 of Set 4 | bluff
# Processing Record 6 of Set 4 | samarai
# Processing Record 7 of Set 4 | platteville
# Processing Record 8 of Set 4 | saldanha
# Processing Record 9 of Set 4 | berdychiv
# Processing Record 10 of Set 4 | ostrovnoy
# Processing Record 11 of Set 4 | vigevano
# Processing Record 12 of Set 4 | sentyabrskiy
# City not found. Skipping...
# Processing Record 13 of Set 4 | zambezi
# Processing Record 14 of Set 4 | te anau
# Processing Record 15 of Set 4 | georgetown
# Processing Record 16 of Set 4 | redmond
# Processing Record 17 of Set 4 | sola
# Processing Record 18 of Set 4 | norman wells
# Processing Record 19 of Set 4 | thompson
# Processing Record 20 of Set 4 | poronaysk
# Processing Record 21 of Set 4 | iqaluit
# Processing Record 22 of Set 4 | pingliang
# Processing Record 23 of Set 4 | fort-shevchenko
# Processing Record 24 of Set 4 | maxixe
# Processing Record 25 of Set 4 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 26 of Set 4 | severo-kurilsk
# Processing Record 27 of Set 4 | omsukchan
# Processing Record 28 of Set 4 | palabuhanratu
# City not found. Skipping...
# Processing Record 29 of Set 4 | bethel
# Processing Record 30 of Set 4 | calvinia
# Processing Record 31 of Set 4 | bembibre
# Processing Record 32 of Set 4 | christchurch
# Processing Record 33 of Set 4 | viedma
# Processing Record 34 of Set 4 | ostrowiec swietokrzyski
# Processing Record 35 of Set 4 | sakaiminato
# Processing Record 36 of Set 4 | tiznit
# Processing Record 37 of Set 4 | longyearbyen
# Processing Record 38 of Set 4 | natal
# Processing Record 39 of Set 4 | poum
# Processing Record 40 of Set 4 | letterkenny
# Processing Record 41 of Set 4 | katsuura
# Processing Record 42 of Set 4 | srivardhan
# Processing Record 43 of Set 4 | ullapool
# Processing Record 44 of Set 4 | ardrishaig
# Processing Record 45 of Set 4 | concepcion
# Processing Record 46 of Set 4 | ahipara
# Processing Record 47 of Set 4 | cabedelo
# Processing Record 48 of Set 4 | avera
# Processing Record 49 of Set 4 | matagami
# Processing Record 50 of Set 4 | tura
# Processing Record 1 of Set 5 | skibbereen
# Processing Record 2 of Set 5 | sorvag
# City not found. Skipping...
# Processing Record 3 of Set 5 | upernavik
# Processing Record 4 of Set 5 | namatanai
# Processing Record 5 of Set 5 | mar del plata
# Processing Record 6 of Set 5 | kaitangata
# Processing Record 7 of Set 5 | cayenne
# Processing Record 8 of Set 5 | waingapu
# Processing Record 9 of Set 5 | banda aceh
# Processing Record 10 of Set 5 | kutum
# Processing Record 11 of Set 5 | half moon bay
# Processing Record 12 of Set 5 | lolua
# City not found. Skipping...
# Processing Record 13 of Set 5 | saco
# Processing Record 14 of Set 5 | khartoum
# Processing Record 15 of Set 5 | saint-georges
# Processing Record 16 of Set 5 | faya
# Processing Record 17 of Set 5 | adelaide
# Processing Record 18 of Set 5 | nikolskoye
# Processing Record 19 of Set 5 | mnogovershinnyy
# Processing Record 20 of Set 5 | reftinskiy
# Processing Record 21 of Set 5 | srednekolymsk
# Processing Record 22 of Set 5 | hurghada
# Processing Record 23 of Set 5 | kobojango
# City not found. Skipping...
# Processing Record 24 of Set 5 | arraial do cabo
# Processing Record 25 of Set 5 | kaspiysk
# Processing Record 26 of Set 5 | lanzhou
# Processing Record 27 of Set 5 | aksu
# Processing Record 28 of Set 5 | dunedin
# Processing Record 29 of Set 5 | rutul
# Processing Record 30 of Set 5 | norilsk
# Processing Record 31 of Set 5 | havre-saint-pierre
# Processing Record 32 of Set 5 | dikson
# Processing Record 33 of Set 5 | wajir
# Processing Record 34 of Set 5 | karratha
# Processing Record 35 of Set 5 | chifeng
# Processing Record 36 of Set 5 | fairbanks
# Processing Record 37 of Set 5 | yulara
# Processing Record 38 of Set 5 | yar-sale
# Processing Record 39 of Set 5 | menongue
# Processing Record 40 of Set 5 | maun
# Processing Record 41 of Set 5 | birin
# Processing Record 42 of Set 5 | sanarate
# Processing Record 43 of Set 5 | kalmunai
# Processing Record 44 of Set 5 | kargopol
# Processing Record 45 of Set 5 | mount isa
# Processing Record 46 of Set 5 | usinsk
# Processing Record 47 of Set 5 | carnarvon
# Processing Record 48 of Set 5 | sao lourenco do sul
# Processing Record 49 of Set 5 | bani
# Processing Record 50 of Set 5 | karaul
# City not found. Skipping...
# Processing Record 1 of Set 6 | kapit
# Processing Record 2 of Set 6 | ust-omchug
# Processing Record 3 of Set 6 | edea
# Processing Record 4 of Set 6 | constantine
# Processing Record 5 of Set 6 | belushya guba
# City not found. Skipping...
# Processing Record 6 of Set 6 | mao
# Processing Record 7 of Set 6 | mahebourg
# Processing Record 8 of Set 6 | progreso
# Processing Record 9 of Set 6 | westport
# Processing Record 10 of Set 6 | broome
# Processing Record 11 of Set 6 | bambous virieux
# Processing Record 12 of Set 6 | conceicao do araguaia
# Processing Record 13 of Set 6 | baneh
# Processing Record 14 of Set 6 | lorengau
# Processing Record 15 of Set 6 | high prairie
# Processing Record 16 of Set 6 | ankazoabo
# Processing Record 17 of Set 6 | cockburn town
# Processing Record 18 of Set 6 | ancud
# Processing Record 19 of Set 6 | saint george
# Processing Record 20 of Set 6 | olinda
# Processing Record 21 of Set 6 | iranshahr
# Processing Record 22 of Set 6 | laguna
# Processing Record 23 of Set 6 | plettenberg bay
# Processing Record 24 of Set 6 | nanortalik
# Processing Record 25 of Set 6 | marica
# Processing Record 26 of Set 6 | viligili
# City not found. Skipping...
# Processing Record 27 of Set 6 | bagdarin
# Processing Record 28 of Set 6 | basco
# Processing Record 29 of Set 6 | centralina
# Processing Record 30 of Set 6 | terenos
# Processing Record 31 of Set 6 | kapoeta
# Processing Record 32 of Set 6 | noumea
# Processing Record 33 of Set 6 | marsh harbour
# Processing Record 34 of Set 6 | skagastrond
# City not found. Skipping...
# Processing Record 35 of Set 6 | mabaruma
# Processing Record 36 of Set 6 | mazara del vallo
# Processing Record 37 of Set 6 | northam
# Processing Record 38 of Set 6 | lizzano
# Processing Record 39 of Set 6 | warwick
# Processing Record 40 of Set 6 | bamora
# Processing Record 41 of Set 6 | vila franca do campo
# Processing Record 42 of Set 6 | yabelo
# Processing Record 43 of Set 6 | jumla
# Processing Record 44 of Set 6 | xinzhi
# Processing Record 45 of Set 6 | balabagan
# Processing Record 46 of Set 6 | santa lucia
# Processing Record 47 of Set 6 | kloulklubed
# Processing Record 48 of Set 6 | margate
# Processing Record 49 of Set 6 | olafsvik
# Processing Record 50 of Set 6 | provideniya
# Processing Record 1 of Set 7 | langham
# Processing Record 2 of Set 7 | kashi
# Processing Record 3 of Set 7 | esperantina
# Processing Record 4 of Set 7 | grand gaube
# Processing Record 5 of Set 7 | rosetta
# Processing Record 6 of Set 7 | kavaratti
# Processing Record 7 of Set 7 | lata
# Processing Record 8 of Set 7 | garissa
# Processing Record 9 of Set 7 | luganville
# Processing Record 10 of Set 7 | boffa
# Processing Record 11 of Set 7 | anaconda
# Processing Record 12 of Set 7 | finschhafen
# Processing Record 13 of Set 7 | clermont
# Processing Record 14 of Set 7 | karamea
# City not found. Skipping...
# Processing Record 15 of Set 7 | omboue
# Processing Record 16 of Set 7 | saint-philippe
# Processing Record 17 of Set 7 | stornoway
# Processing Record 18 of Set 7 | sao marcos
# Processing Record 19 of Set 7 | soure
# Processing Record 20 of Set 7 | harper
# Processing Record 21 of Set 7 | jieshi
# Processing Record 22 of Set 7 | naze
# Processing Record 23 of Set 7 | saint-augustin
# Processing Record 24 of Set 7 | vao
# Processing Record 25 of Set 7 | tabas
# Processing Record 26 of Set 7 | pando
# Processing Record 27 of Set 7 | bathsheba
# Processing Record 28 of Set 7 | sao felix do xingu
# Processing Record 29 of Set 7 | upata
# Processing Record 30 of Set 7 | namibe
# Processing Record 31 of Set 7 | yanam
# Processing Record 32 of Set 7 | mendoza
# Processing Record 33 of Set 7 | pochutla
# Processing Record 34 of Set 7 | svetlogorsk
# Processing Record 35 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 36 of Set 7 | kirovskiy
# Processing Record 37 of Set 7 | talkha
# Processing Record 38 of Set 7 | bengkulu
# Processing Record 39 of Set 7 | bukama
# Processing Record 40 of Set 7 | kavieng
# Processing Record 41 of Set 7 | boshan
# Processing Record 42 of Set 7 | grand junction
# Processing Record 43 of Set 7 | tigil
# Processing Record 44 of Set 7 | gornopravdinsk
# Processing Record 45 of Set 7 | escarcega
# Processing Record 46 of Set 7 | codrington
# Processing Record 47 of Set 7 | arlit
# Processing Record 48 of Set 7 | madinat sittah uktubar
# Processing Record 49 of Set 7 | vardo
# Processing Record 50 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 1 of Set 8 | alapur
# Processing Record 2 of Set 8 | launceston
# Processing Record 3 of Set 8 | sayat
# Processing Record 4 of Set 8 | the valley
# Processing Record 5 of Set 8 | mys shmidta
# City not found. Skipping...
# Processing Record 6 of Set 8 | adrar
# Processing Record 7 of Set 8 | sao joao da barra
# Processing Record 8 of Set 8 | sao filipe
# Processing Record 9 of Set 8 | ye
# City not found. Skipping...
# Processing Record 10 of Set 8 | daokou
# Processing Record 11 of Set 8 | high rock
# Processing Record 12 of Set 8 | yasnyy
# Processing Record 13 of Set 8 | palmas
# Processing Record 14 of Set 8 | louisbourg
# City not found. Skipping...
# Processing Record 15 of Set 8 | warrenton
# Processing Record 16 of Set 8 | puerto ayacucho
# Processing Record 17 of Set 8 | marshall
# Processing Record 18 of Set 8 | puerto madryn
# Processing Record 19 of Set 8 | vostok
# Processing Record 20 of Set 8 | aklavik
# Processing Record 21 of Set 8 | paldiski
# Processing Record 22 of Set 8 | baturaja
# Processing Record 23 of Set 8 | narsaq
# Processing Record 24 of Set 8 | quatre cocos
# Processing Record 25 of Set 8 | jaguarao
# Processing Record 26 of Set 8 | oksfjord
# Processing Record 27 of Set 8 | lawigan
# Processing Record 28 of Set 8 | norsup
# Processing Record 29 of Set 8 | maragogi
# Processing Record 30 of Set 8 | petropavlovsk-kamchatskiy
# Processing Record 31 of Set 8 | gualeguaychu
# Processing Record 32 of Set 8 | wanlaweyn
# Processing Record 33 of Set 8 | dhidhdhoo
# Processing Record 34 of Set 8 | harnosand
# Processing Record 35 of Set 8 | kazalinsk
# City not found. Skipping...
# Processing Record 36 of Set 8 | meridian
# Processing Record 37 of Set 8 | udachnyy
# Processing Record 38 of Set 8 | katherine
# Processing Record 39 of Set 8 | winona
# Processing Record 40 of Set 8 | boyolangu
# Processing Record 41 of Set 8 | cruzeiro
# Processing Record 42 of Set 8 | nizwa
# Processing Record 43 of Set 8 | manama
# Processing Record 44 of Set 8 | abdanan
# Processing Record 45 of Set 8 | nautanwa
# Processing Record 46 of Set 8 | usta muhammad
# Processing Record 47 of Set 8 | dovolnoye
# Processing Record 48 of Set 8 | neiafu
# Processing Record 49 of Set 8 | santa rosalia
# Processing Record 50 of Set 8 | linden
# Processing Record 1 of Set 9 | ganta
# Processing Record 2 of Set 9 | serebryanyy bor
# Processing Record 3 of Set 9 | rio grande city
# Processing Record 4 of Set 9 | iwanai
# Processing Record 5 of Set 9 | coihaique
# Processing Record 6 of Set 9 | pisco
# Processing Record 7 of Set 9 | ulaanbaatar
# Processing Record 8 of Set 9 | palmer
# Processing Record 9 of Set 9 | satitoa
# City not found. Skipping...
# Processing Record 10 of Set 9 | saint anthony
# Processing Record 11 of Set 9 | chicama
# Processing Record 12 of Set 9 | fare
# Processing Record 13 of Set 9 | marystown
# Processing Record 14 of Set 9 | grants pass
# Processing Record 15 of Set 9 | dabakala
# Processing Record 16 of Set 9 | moindou
# Processing Record 17 of Set 9 | hays
# Processing Record 18 of Set 9 | talnakh
# Processing Record 19 of Set 9 | pulandian
# Processing Record 20 of Set 9 | kudahuvadhoo
# Processing Record 21 of Set 9 | tutoia
# Processing Record 22 of Set 9 | alofi
# Processing Record 23 of Set 9 | telchac
# Processing Record 24 of Set 9 | pangai
# Processing Record 25 of Set 9 | acajutla
# Processing Record 26 of Set 9 | san quintin
# Processing Record 27 of Set 9 | kirakira
# Processing Record 28 of Set 9 | ust-nera
# Processing Record 29 of Set 9 | turayf
# Processing Record 30 of Set 9 | kathu
# Processing Record 31 of Set 9 | svetlyy
# Processing Record 32 of Set 9 | pangnirtung
# Processing Record 33 of Set 9 | miraflores
# Processing Record 34 of Set 9 | coquimbo
# Processing Record 35 of Set 9 | urumqi
# Processing Record 36 of Set 9 | hailey
# Processing Record 37 of Set 9 | mount gambier
# Processing Record 38 of Set 9 | lompoc
# Processing Record 39 of Set 9 | diffa
# Processing Record 40 of Set 9 | adeje
# Processing Record 41 of Set 9 | yaring
# Processing Record 42 of Set 9 | neryungri
# Processing Record 43 of Set 9 | ust-maya
# Processing Record 44 of Set 9 | kaeo
# Processing Record 45 of Set 9 | chamalieres
# Processing Record 46 of Set 9 | erenhot
# Processing Record 47 of Set 9 | alta floresta
# Processing Record 48 of Set 9 | bonfim
# Processing Record 49 of Set 9 | las cruces
# Processing Record 50 of Set 9 | tiarei
# Processing Record 1 of Set 10 | hervey bay
# Processing Record 2 of Set 10 | valparaiso
# Processing Record 3 of Set 10 | fort nelson
# Processing Record 4 of Set 10 | sao gabriel da cachoeira
# Processing Record 5 of Set 10 | flinders
# Processing Record 6 of Set 10 | luanshya
# Processing Record 7 of Set 10 | itarema
# Processing Record 8 of Set 10 | tumannyy
# City not found. Skipping...
# Processing Record 9 of Set 10 | lujan
# Processing Record 10 of Set 10 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 10 | cherskiy
# Processing Record 12 of Set 10 | nome
# Processing Record 13 of Set 10 | piacabucu
# Processing Record 14 of Set 10 | tilichiki
# Processing Record 15 of Set 10 | sampang
# Processing Record 16 of Set 10 | nova odesa
# Processing Record 17 of Set 10 | eyl
# Processing Record 18 of Set 10 | gisborne
# Processing Record 19 of Set 10 | arkadelphia
# Processing Record 20 of Set 10 | meadow lake
# Processing Record 21 of Set 10 | riyadh
# Processing Record 22 of Set 10 | dawlatabad
# Processing Record 23 of Set 10 | fallon
# Processing Record 24 of Set 10 | hornepayne
# Processing Record 25 of Set 10 | bilibino
# Processing Record 26 of Set 10 | thaba-tseka
# Processing Record 27 of Set 10 | gelemso
# Processing Record 28 of Set 10 | port blair
# Processing Record 29 of Set 10 | khingansk
# Processing Record 30 of Set 10 | kismayo
# Processing Record 31 of Set 10 | panzhihua
# Processing Record 32 of Set 10 | komoro
# Processing Record 33 of Set 10 | acari
# Processing Record 34 of Set 10 | la ronge
# Processing Record 35 of Set 10 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 10 | suao
# City not found. Skipping...
# Processing Record 37 of Set 10 | tautira
# Processing Record 38 of Set 10 | raudeberg
# Processing Record 39 of Set 10 | mildura
# Processing Record 40 of Set 10 | mount darwin
# Processing Record 41 of Set 10 | san felipe
# Processing Record 42 of Set 10 | shenjiamen
# Processing Record 43 of Set 10 | sumenep
# Processing Record 44 of Set 10 | caala
# Processing Record 45 of Set 10 | ratnagiri
# Processing Record 46 of Set 10 | bur gabo
# City not found. Skipping...
# Processing Record 47 of Set 10 | gizo
# Processing Record 48 of Set 10 | fenyi
# Processing Record 49 of Set 10 | ixtapa
# Processing Record 50 of Set 10 | pecos
# Processing Record 1 of Set 11 | zheleznodorozhnyy
# Processing Record 2 of Set 11 | zhigansk
# Processing Record 3 of Set 11 | tessalit
# Processing Record 4 of Set 11 | malwan
# City not found. Skipping...
# Processing Record 5 of Set 11 | udarnyy
# Processing Record 6 of Set 11 | san antero
# Processing Record 7 of Set 11 | uyemskiy
# Processing Record 8 of Set 11 | berwick
# Processing Record 9 of Set 11 | santa rosa
# Processing Record 10 of Set 11 | acapulco
# Processing Record 11 of Set 11 | alcaniz
# Processing Record 12 of Set 11 | saint-joseph
# Processing Record 13 of Set 11 | los banos
# Processing Record 14 of Set 11 | san cristobal
# Processing Record 15 of Set 11 | verkhoyansk
# Processing Record 16 of Set 11 | rawannawi
# City not found. Skipping...
# Processing Record 17 of Set 11 | feicheng
# Processing Record 18 of Set 11 | xiongshi
# City not found. Skipping...
# Processing Record 19 of Set 11 | cervo
# Processing Record 20 of Set 11 | necochea
# Processing Record 21 of Set 11 | turukhansk
# Processing Record 22 of Set 11 | sakhon nakhon
# Processing Record 23 of Set 11 | constitucion
# Processing Record 24 of Set 11 | shelabolikha
# Processing Record 25 of Set 11 | novyy urengoy
# Processing Record 26 of Set 11 | lumeje
# Processing Record 27 of Set 11 | vanavara
# Processing Record 28 of Set 11 | kununurra
# Processing Record 29 of Set 11 | pakruojis
# Processing Record 30 of Set 11 | burnie
# Processing Record 31 of Set 11 | sorland
# Processing Record 32 of Set 11 | caiaponia
# Processing Record 33 of Set 11 | peniche
# Processing Record 34 of Set 11 | korla
# Processing Record 35 of Set 11 | muros
# Processing Record 36 of Set 11 | zabaykalsk
# Processing Record 37 of Set 11 | yerbogachen
# Processing Record 38 of Set 11 | santa luzia
# Processing Record 39 of Set 11 | manica
# Processing Record 40 of Set 11 | kamina
# Processing Record 41 of Set 11 | jeremie
# Processing Record 42 of Set 11 | sembakung
# Processing Record 43 of Set 11 | tarnogskiy gorodok
# Processing Record 44 of Set 11 | mahadday weyne
# City not found. Skipping...
# Processing Record 45 of Set 11 | gurlan
# Processing Record 46 of Set 11 | abdulino
# Processing Record 47 of Set 11 | chengannur
# Processing Record 48 of Set 11 | atbasar
# Processing Record 49 of Set 11 | selje
# Processing Record 50 of Set 11 | yumen
# Processing Record 1 of Set 12 | tungkang
# City not found. Skipping...
# Processing Record 2 of Set 12 | filadelfia
# Processing Record 3 of Set 12 | kirkenes
# Processing Record 4 of Set 12 | port-gentil
# Processing Record 5 of Set 12 | mongomo
# Processing Record 6 of Set 12 | kotlyarevskaya
# Processing Record 7 of Set 12 | black river
# Processing Record 8 of Set 12 | atherton
# Processing Record 9 of Set 12 | williamsport
# Processing Record 10 of Set 12 | marovoay
# Processing Record 11 of Set 12 | karakol
# Processing Record 12 of Set 12 | padang
# Processing Record 13 of Set 12 | wanxian
# Processing Record 14 of Set 12 | nemuro
# Processing Record 15 of Set 12 | naryan-mar
# Processing Record 16 of Set 12 | cervantes
# Processing Record 17 of Set 12 | siderno
# Processing Record 18 of Set 12 | koson
# Processing Record 19 of Set 12 | himora
# City not found. Skipping...
# Processing Record 20 of Set 12 | ituni
# City not found. Skipping...
# Processing Record 21 of Set 12 | edendale
# Processing Record 22 of Set 12 | husavik
# Processing Record 23 of Set 12 | veraval
# Processing Record 24 of Set 12 | hami
# Processing Record 25 of Set 12 | zhezkazgan
# Processing Record 26 of Set 12 | capinopolis
# Processing Record 27 of Set 12 | zyryanovskiy
# City not found. Skipping...
# Processing Record 28 of Set 12 | abingdon
# Processing Record 29 of Set 12 | grand river south east
# City not found. Skipping...
# Processing Record 30 of Set 12 | barras
# Processing Record 31 of Set 12 | jalu
# Processing Record 32 of Set 12 | guangyuan
# Processing Record 33 of Set 12 | redlands
# Processing Record 34 of Set 12 | lasa
# Processing Record 35 of Set 12 | tawkar
# City not found. Skipping...
# Processing Record 36 of Set 12 | trapani
# Processing Record 37 of Set 12 | hay river
# Processing Record 38 of Set 12 | buin
# Processing Record 39 of Set 12 | petawawa
# Processing Record 40 of Set 12 | alekseyevka
# Processing Record 41 of Set 12 | jackson
# Processing Record 42 of Set 12 | chimbote
# Processing Record 43 of Set 12 | buala
# Processing Record 44 of Set 12 | tibati
# Processing Record 45 of Set 12 | blackwater
# Processing Record 46 of Set 12 | mizdah
# Processing Record 47 of Set 12 | teshie
# Processing Record 48 of Set 12 | ciuruleasa
# Processing Record 49 of Set 12 | san ramon
# Processing Record 50 of Set 12 | filimonovo
# Processing Record 1 of Set 13 | brae
# Processing Record 2 of Set 13 | shache
# Processing Record 3 of Set 13 | olga
# Processing Record 4 of Set 13 | kahului
# Processing Record 5 of Set 13 | cadillac
# Processing Record 6 of Set 13 | charlestown
# Processing Record 7 of Set 13 | puquio
# Processing Record 8 of Set 13 | humaita
# Processing Record 9 of Set 13 | valleyview
# Processing Record 10 of Set 13 | saint-paul
# Processing Record 11 of Set 13 | nenagh
# Processing Record 12 of Set 13 | ocos
# Processing Record 13 of Set 13 | galle
# Processing Record 14 of Set 13 | baboua
# City not found. Skipping...
# Processing Record 15 of Set 13 | lalmohan
# Processing Record 16 of Set 13 | darlowo
# Processing Record 17 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 18 of Set 13 | derzhavinsk
# Processing Record 19 of Set 13 | manggar
# Processing Record 20 of Set 13 | miandrivazo
# Processing Record 21 of Set 13 | ballina
# Processing Record 22 of Set 13 | tanggu
# Processing Record 23 of Set 13 | havelock
# Processing Record 24 of Set 13 | gat
# Processing Record 25 of Set 13 | altay
# Processing Record 26 of Set 13 | lagos
# Processing Record 27 of Set 13 | ulverstone
# Processing Record 28 of Set 13 | ystad
# Processing Record 29 of Set 13 | nizhniy kuranakh
# Processing Record 30 of Set 13 | mezen
# Processing Record 31 of Set 13 | bac giang
# Processing Record 32 of Set 13 | ongole
# Processing Record 33 of Set 13 | deputatskiy
# Processing Record 34 of Set 13 | obzor
# Processing Record 35 of Set 13 | anito
# Processing Record 36 of Set 13 | cap malheureux
# Processing Record 37 of Set 13 | koslan
# Processing Record 38 of Set 13 | mengen
# Processing Record 39 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 40 of Set 13 | lewiston
# Processing Record 41 of Set 13 | nantucket
# Processing Record 42 of Set 13 | thyboron
# Processing Record 43 of Set 13 | quilmana
# Processing Record 44 of Set 13 | nabire
# Processing Record 45 of Set 13 | odienne
# Processing Record 46 of Set 13 | pemangkat
# Processing Record 47 of Set 13 | ko samui
# Processing Record 48 of Set 13 | ust-charyshskaya pristan
# Processing Record 49 of Set 13 | mitsamiouli
# Processing Record 50 of Set 13 | odweyne
# Processing Record 1 of Set 14 | karkaralinsk
# City not found. Skipping...
# Processing Record 2 of Set 14 | yakshur-bodya
# City not found. Skipping...
# Processing Record 3 of Set 14 | angoche
# Processing Record 4 of Set 14 | abu samrah
# Processing Record 5 of Set 14 | tual
# Processing Record 6 of Set 14 | port augusta
# Processing Record 7 of Set 14 | vung tau
# Processing Record 8 of Set 14 | salgueiro
# Processing Record 9 of Set 14 | green river
# Processing Record 10 of Set 14 | phumi samraong
# City not found. Skipping...
# Processing Record 11 of Set 14 | catanduva
# Processing Record 12 of Set 14 | cuamba
# Processing Record 13 of Set 14 | salina
# Processing Record 14 of Set 14 | ossora
# Processing Record 15 of Set 14 | atar
# Processing Record 16 of Set 14 | khonuu
# City not found. Skipping...
# Processing Record 17 of Set 14 | ketchikan
# Processing Record 18 of Set 14 | mullaitivu
# City not found. Skipping...
# Processing Record 19 of Set 14 | vila
# Processing Record 20 of Set 14 | kokkola
# Processing Record 21 of Set 14 | izumo
# Processing Record 22 of Set 14 | ponta delgada
# Processing Record 23 of Set 14 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 14 | rosia montana
# City not found. Skipping...
# Processing Record 25 of Set 14 | iquitos
# Processing Record 26 of Set 14 | luderitz
# Processing Record 27 of Set 14 | teya
# Processing Record 28 of Set 14 | belmonte
# Processing Record 29 of Set 14 | laguna beach
# Processing Record 30 of Set 14 | dawei
# Processing Record 31 of Set 14 | windhoek
# Processing Record 32 of Set 14 | ustyuzhna
# Processing Record 33 of Set 14 | campbellton
# Processing Record 34 of Set 14 | acarau
# Processing Record 35 of Set 14 | arys
# Processing Record 36 of Set 14 | gazojak
# Processing Record 37 of Set 14 | pimentel
# Processing Record 38 of Set 14 | dandong
# Processing Record 39 of Set 14 | amuntai
# Processing Record 40 of Set 14 | hobyo
# Processing Record 41 of Set 14 | dezhou
# Processing Record 42 of Set 14 | micheweni
# Processing Record 43 of Set 14 | tocopilla
# Processing Record 44 of Set 14 | verkhnevilyuysk
# Processing Record 45 of Set 14 | gravdal
# Processing Record 46 of Set 14 | pinar del rio
# Processing Record 47 of Set 14 | gazanjyk
# Processing Record 48 of Set 14 | ashland
# Processing Record 49 of Set 14 | santa cruz de la palma
# Processing Record 50 of Set 14 | ca mau
# Processing Record 1 of Set 15 | freeport
# Processing Record 2 of Set 15 | port macquarie
# Processing Record 3 of Set 15 | grindavik
# Processing Record 4 of Set 15 | camara de lobos
# Processing Record 5 of Set 15 | alotau
# City not found. Skipping...
# Processing Record 6 of Set 15 | san jose
# Processing Record 7 of Set 15 | zhob
# Processing Record 8 of Set 15 | izberbash
# Processing Record 9 of Set 15 | ventspils
# Processing Record 10 of Set 15 | madaoua
# Processing Record 11 of Set 15 | gamba
# Processing Record 12 of Set 15 | kokopo
# Processing Record 13 of Set 15 | kalashnikovo
# Processing Record 14 of Set 15 | abu kamal
# Processing Record 15 of Set 15 | minot
# Processing Record 16 of Set 15 | tazovskiy
# Processing Record 17 of Set 15 | dharmabad
# Processing Record 18 of Set 15 | ust-shonosha
# Processing Record 19 of Set 15 | tadine
# Processing Record 20 of Set 15 | vilaka
# Processing Record 21 of Set 15 | gogrial
# Processing Record 22 of Set 15 | taoudenni
# Processing Record 23 of Set 15 | kieta
# Processing Record 24 of Set 15 | teknaf
# Processing Record 25 of Set 15 | tabora
# Processing Record 26 of Set 15 | sterling
# Processing Record 27 of Set 15 | thinadhoo
# Processing Record 28 of Set 15 | kerteh
# City not found. Skipping...
# Processing Record 29 of Set 15 | batemans bay
# Processing Record 30 of Set 15 | debre birhan
# Processing Record 31 of Set 15 | dimitrovgrad
# Processing Record 32 of Set 15 | marin
# Processing Record 33 of Set 15 | knysna
# Processing Record 34 of Set 15 | porto-vecchio
# Processing Record 35 of Set 15 | dolores
# Processing Record 36 of Set 15 | mambajao
# Processing Record 37 of Set 15 | abbeville
# Processing Record 38 of Set 15 | nisia floresta
# Processing Record 39 of Set 15 | sibolga
# Processing Record 40 of Set 15 | pitiquito
# Processing Record 41 of Set 15 | beyneu
# Processing Record 42 of Set 15 | kotaparh
# Processing Record 43 of Set 15 | usak
# Processing Record 44 of Set 15 | abalak
# Processing Record 45 of Set 15 | kimbe
# Processing Record 46 of Set 15 | ozinki
# Processing Record 47 of Set 15 | las vegas
# Processing Record 48 of Set 15 | paso de carrasco
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 688

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = pd.DataFrame(city_data)

# %%
# Display sample data
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Doume   4.2333   13.4500     68.95        98          83
# 1      Ambilobe -13.2000   49.0500     74.59        90          99
# 2       Mataura -46.1927  168.8643     57.47        98         100
# 3       Ushuaia -54.8000  -68.3000     44.26        65          40
# 4          Hilo  19.7297 -155.0900     83.28        79          32
# 5       Shimoda  34.6667  138.9500     52.11        92         100
# 6  San Patricio  28.0170  -97.5169     94.15        27           0
# 7      Tiblawan   6.4783  126.1083     80.94        79          71
# 8         Vaini -21.2000 -175.2000     84.36        79          75
# 9  Ponta Do Sol  32.6667  -17.1000     63.72        77          14
#
#    Wind Speed Country           Weather                 Date
# 0        3.78      CM     moderate rain  2023-03-24 22:10:05
# 1        2.89      MG   overcast clouds  2023-03-24 22:10:05
# 2        3.89      NZ   overcast clouds  2023-03-24 22:10:07
# 3       26.46      AR  scattered clouds  2023-03-24 22:10:08
# 4        7.00      US  scattered clouds  2023-03-24 22:01:55
# 5       19.42      JP        light rain  2023-03-24 22:10:08
# 6       14.38      US         clear sky  2023-03-24 22:02:40
# 7        9.40      PH     broken clouds  2023-03-24 22:02:40
# 8        9.22      TO     broken clouds  2023-03-24 22:10:10
# 9        6.06      PT        few clouds  2023-03-24 22:02:41

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Country', 'Lat', 'Lng', 'Max Temp', 'Humidity', 'Cloudiness',
#        'Wind Speed', 'Weather'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed","Weather"]



# Recreate the DataFrame by using the new column order
city_data_df = city_data_df[new_column_order]

# Display sample data
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Doume      CM   4.2333   13.4500     68.95        98          83
# 1      Ambilobe      MG -13.2000   49.0500     74.59        90          99
# 2       Mataura      NZ -46.1927  168.8643     57.47        98         100
# 3       Ushuaia      AR -54.8000  -68.3000     44.26        65          40
# 4          Hilo      US  19.7297 -155.0900     83.28        79          32
# 5       Shimoda      JP  34.6667  138.9500     52.11        92         100
# 6  San Patricio      US  28.0170  -97.5169     94.15        27           0
# 7      Tiblawan      PH   6.4783  126.1083     80.94        79          71
# 8         Vaini      TO -21.2000 -175.2000     84.36        79          75
# 9  Ponta Do Sol      PT  32.6667  -17.1000     63.72        77          14
#
#    Wind Speed           Weather
# 0        3.78     moderate rain
# 1        2.89   overcast clouds
# 2        3.89   overcast clouds
# 3       26.46  scattered clouds
# 4        7.00  scattered clouds
# 5       19.42        light rain
# 6       14.38         clear sky
# 7        9.40     broken clouds
# 8        9.22     broken clouds
# 9        6.06        few clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City           object
# Country        object
# Lat           float64
# Lng           float64
# Max Temp      float64
# Humidity        int64
# Cloudiness      int64
# Wind Speed    float64
# Weather        object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
output_data_file = "WeatherPy_Database.csv"

# Export the city_data DataFrame into a CSV file
city_data_df.to_csv(output_data_file, index_label="City_ID")
